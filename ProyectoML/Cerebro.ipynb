# %% [markdown]
# <a href="https://colab.research.google.com/github/Emyfoton/MetodosI_EmilyCastillo_SebastianRodriguez/blob/main/ProyectoML/Cerebro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sigm = lambda x: 1/(1+np.exp(-x))

# %%
x = np.linspace(-10,10,100)
y = sigm(x)

# %%
#plt.plot(x,y)

# %%
class Layer:

  def __init__(self,NC,NN, ActFunc):

    self.NC = NC
    self.NN = NN
    self.ActFunc = ActFunc

    self.W = np.random.uniform(-10,10, size=(self.NC,self.NN))
    self.b = np.random.uniform(-10,10, size=(1,self.NN))

  def Activation(self,x):
    z = np.dot(x,self.W) + self.b
    return self.ActFunc(z)

# %%
l0 = Layer(2,2,sigm)

# %%
l0.W
# Out:
# array([[ 5.72810251, -4.86918287],
#        [-1.85757545,  6.2094519 ]])

# %%
l0.b
# Out:
# array([[-0.68257781, -5.07361021]])

# %%
l0.Activation(np.array([0,0]))[0]
# Out:
# array([0.33568621, 0.00622084])

# %%
x = np.linspace(-1,1,50)
y = np.linspace(-1,1,50)
X,Y = np.meshgrid(x,y)
N = np.zeros_like(X)
N1 = np.zeros_like(X)

for i in range(50):
  for j in range(50):
    N[i,j] = l0.Activation(np.array([x[i],y[j]]))[0][0]
    N1[i,j] = l0.Activation(np.array([x[i],y[j]]))[0][1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,N)
ax.plot_surface(X,Y,N1)
