# %% [markdown]
# <a href="https://colab.research.google.com/github/Emyfoton/MetodosI_EmilyCastillo_SebastianRodriguez/blob/main/Algorit_Metropolis_editado_por_Emy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib  import cm
from IPython.display import clear_output
import time
from tqdm import tqdm

# %%
def GetPlot():

    fig = plt.figure(figsize=(15,4))
    ax = fig.add_subplot(1,2,1)
    ax1 = fig.add_subplot(1,2,2)

    return ax,ax1

# %%
def Likelihood(x,p):
  mu,sigma = p
  return 1/(np.sqrt(2*np.pi*sigma**2))*np.exp(-(x-mu)**2/(2*sigma**2))

# %%
def Metropolis(Likelihood, p, x0=-10, a=1, NSteps=int(1e3), burned=1000):

  x = np.zeros(NSteps)
  x[0] = x0

  accept = 0

  for i in range(NSteps-1):

    # Donde estoy
    p0 = Likelihood(x[i],p)

    # Guess
    xn1 = x[i] + a*np.random.uniform(-1,1)

    p1 = Likelihood(xn1,p)

    alpha = np.minimum(1, p1/p0)

    g = np.random.rand()

    if g < alpha:
      x[i+1] = xn1
      accept += 1
    else:
      x[i+1] = x[i]

    if i % 500 == 0:
     # print(p1,p0)
      clear_output(wait=True)
      ax,ax1 = GetPlot()
      ax.plot(x[:i+1],'-',color='k')

      _x = np.linspace(np.min(x),np.max(x),30)
      ax1.plot(_x,Likelihood(_x,p),color='r')
      ax1.hist(x[:i+1],bins=40,density=True,color='b')
      ax1.set_xlabel('x')
      plt.show()

  return x

# %%
p0 = np.array([5,2])
x = Metropolis(Likelihood, p0, NSteps=int(1e4))

# %%
plt.hist(x)
# Out:
# (array([   9.,   10.,    7.,   33.,  284., 1695., 3772., 3122.,  951.,
#          117.]),
#  array([-10.        ,  -7.79726966,  -5.59453932,  -3.39180898,
#          -1.18907864,   1.0136517 ,   3.21638204,   5.41911238,
#           7.62184272,   9.82457306,  12.0273034 ]),
#  <BarContainer object of 10 artists>)
